# %%
import seaborn as sns
import numpy as np

# %% [markdown]
# # query

# %% [markdown]
# Provide the python code for plotting the density of cells in umap embedding with the API only from Scanpy. Apply it to the built-in pbmc3k processed dataset.

# %% [markdown]
# # old

# %% [markdown]
# # new

# %%
import scanpy as sc

# Load PBMC 3k dataset
adata = sc.datasets.pbmc3k_processed()

# Check if UMAP is already computed
if 'X_umap' not in adata.obsm.keys():
    sc.tl.pca(adata)
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)

# Plot UMAP with density estimation
sc.pl.umap(adata, color='louvain', use_raw=False, size=30, density=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 13
#      10     sc.tl.umap(adata)
#      12 # Plot UMAP with density estimation
# ---> 13 sc.pl.umap(adata, color='louvain', use_raw=False, size=30, density=True)
#
# File /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:683, in umap(adata, **kwargs)
#     624 @_wraps_plot_scatter
#     625 @_doc_params(
#     626     adata_color_etc=doc_adata_color_etc,
#    (...)
#     630 )
#     631 def umap(adata: AnnData, **kwargs) -> Figure | Axes | list[Axes] | None:
#     632     """\
#     633     Scatter plot in UMAP basis.
#     634
#    (...)
#     681     tl.umap
#     682     """
# --> 683     return embedding(adata, "umap", **kwargs)
#
# ...

# %% [markdown]
# ### gpt4 confuses umap() with embedding_density() API. gpt4 thinks it should use umap() with specifying "density" arg, where "density" is not existing.
#
# ### For biomania, it better not "generate API and args at first then deal with arg problem", it should be predict APi and predict args one by one. after prediction, agent should self-reflect whether the generated API and args can satisfy the objective.
#
# ### current bimania interaction logic makes no sense. Indeed, preprocessing steps are fixed, the steps should refer to the document, so no need to give users API selections. the final API selections are needed.

# %%
import scanpy as sc

# Load PBMC 3k dataset
adata = sc.datasets.pbmc3k_processed()

# Check if UMAP is already computed
if 'X_umap' not in adata.obsm.keys():
    sc.tl.pca(adata)
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)

# %%
sc.tl.embedding_density(adata, basis='umap')

# %%
sc.pl.embedding_density(
    adata, basis='umap'
)
