# %%
import seaborn as sns
import numpy as np

# %% [markdown]
# ### here, the first time that the problem resulted from the inability of accessing data contents of gpt4 occurs.

# %% [markdown]
# # query

# %% [markdown]
# Provide the python code for visualizing the genes expression values through violin figure with the API only from Scanpy. Apply it to the built-in pbmc3k processed dataset.

# %% [markdown]
# # old

# %%
import scanpy as sc
import pandas as pd


# Load the example pbmc3k dataset from Scanpy datasets
adata = sc.datasets.pbmc3k_processed()

# Check the data (optional)
print(adata)

# Normalize data to ensure meaningful visualization
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# Choose a list of genes you want to visualize.
# For demonstration, let's arbitrarily pick some typical immune cell markers.
genes_to_plot = ['CD3D', 'CD3E', 'CD19', 'CD34', 'LYZ']  # Adjust the list based on your focus.

# Visualize the expression of these genes using violin plot
sc.pl.violin(adata, keys=genes_to_plot, jitter=True)
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'draw_graph', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_draw_graph_fr'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'
# /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:234: UserWarning: Some cells have zero counts
#   warn(UserWarning("Some cells have zero counts"))
# /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/preprocessing/_simple.py:383: RuntimeWarning: invalid value encountered in log1p
#   np.log1p(X, out=X)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 20
#      17 genes_to_plot = ['CD3D', 'CD3E', 'CD19', 'CD34', 'LYZ']  # Adjust the list based on your focus.
#      19 # Visualize the expression of these genes using violin plot
# ---> 20 sc.pl.violin(adata, keys=genes_to_plot, jitter=True)
#
# File /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:867, in violin(***failed resolving arguments***)
#     863         kwds["palette"] = dict(
#     864             zip(obs_df[groupby].cat.categories, adata.uns[f"{groupby}_colors"])
#     865         )
#     866 else:
# --> 867     obs_df = get.obs_df(adata, keys=keys, layer=layer, use_raw=use_raw)
#     868 if groupby is None:
#     869     obs_tidy = pd.melt(obs_df, value_vars=keys)
#
# File /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/get/get.py:292, in obs_df(adata, keys, obsm_keys, layer, gene_symbols, use_raw)
#     289     var = adata.var
#     290 alias_index = pd.Index(var[gene_symbols]) if gene_symbols is not None else None
# --> 292 obs_cols, var_idx_keys, var_symbols = _check_indices(
#     293     adata.obs,
#     294     var.index,
#     295     dim="obs",
#     296     keys=keys,
#     297     alias_index=alias_index,
#     298     use_raw=use_raw,
#     299 )
#     301 # Make df
#     302 df = pd.DataFrame(index=adata.obs_names)
#
# File /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/get/get.py:183, in _check_indices(dim_df, alt_index, dim, keys, alias_index, use_raw)
#     181         not_found.append(key)
#     182 if len(not_found) > 0:
# --> 183     raise KeyError(
#     184         f"Could not find keys '{not_found}' in columns of `adata.{dim}` or in"
#     185         f" {alt_repr}.{alt_search_repr}."
#     186     )
#     188 return col_keys, index_keys, index_aliases
#
# KeyError: "Could not find keys '['CD34']' in columns of `adata.obs` or in adata.raw.var_names."

# %% [markdown]
# ### although normalize_total and log1p should be removed here, since they are not key problems in this case, we don't remove them for fair comparison.
#
# ### gpt4 don't know gene names in adata.

# %%
adata.var_names
# Out:
# Index(['TNFRSF4', 'CPSF3L', 'ATAD3C', 'C1orf86', 'RER1', 'TNFRSF25', 'TNFRSF9',
#        'CTNNBIP1', 'SRM', 'UBIAD1',
#        ...
#        'DSCR3', 'BRWD1', 'BACE2', 'SIK1', 'C21orf33', 'ICOSLG', 'SUMO3',
#        'SLC19A1', 'S100B', 'PRMT2'],
#       dtype='object', name='index', length=1838)

# %%
import scanpy as sc
import pandas as pd


# Load the example pbmc3k dataset from Scanpy datasets
adata = sc.datasets.pbmc3k_processed()

# Check the data (optional)
print(adata)

# Normalize data to ensure meaningful visualization
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# Choose a list of genes you want to visualize.
# For demonstration, let's arbitrarily pick some typical immune cell markers.
genes_to_plot = ['TNFRSF4', 'CPSF3L', 'ATAD3C']  # Adjust the list based on your focus.

# Visualize the expression of these genes using violin plot
sc.pl.violin(adata, keys=genes_to_plot, jitter=True)
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'draw_graph', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_draw_graph_fr'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'
# /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:234: UserWarning: Some cells have zero counts
#   warn(UserWarning("Some cells have zero counts"))
# /opt/anaconda3/envs/bioma/lib/python3.11/site-packages/scanpy/preprocessing/_simple.py:383: RuntimeWarning: invalid value encountered in log1p
#   np.log1p(X, out=X)

# %% [markdown]
# ### great! problem resolved

# %% [markdown]
# # new
#
# ### no prblem
